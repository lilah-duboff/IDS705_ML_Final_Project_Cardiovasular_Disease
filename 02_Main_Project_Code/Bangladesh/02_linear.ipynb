# %% [markdown]
# # Using a Linear model to predict Continuous Risk Score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
x_train_7 = x_train_7.reshape(-1, 1)
x_test_7 = x_test_7.reshape(-1, 1)
linear_model = LinearRegression()
linear_model.fit(x_train_7, y_train_7)
# Isolate the coefficients (a0, a1)
a0b = linear_model.intercept_
a1b = linear_model.coef_[0]
# Training data y value predictions
y_train_pred_b = linear_model.predict(x_train_7)
# R^2
r2b = r2_score(y_train_7, y_train_pred_b)
# Mean Square Error (MSE)
mseb = mean_squared_error(y_train_7, y_train_pred_b)
print(f"The estimated model is: y = {a0b:.2f} + {a1b:.2f}x")
print(f"The calculated R^2 value is: {r2b:.4f}")
print(f"The mean square error: {mseb:.4f}")
